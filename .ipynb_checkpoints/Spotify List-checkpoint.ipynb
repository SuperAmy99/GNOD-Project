# %% [markdown]
# ## Web Scraping: Create a list of top_200_songs

# %% [markdown]
# ### Web Scraping Popvortex

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# check that the html code looks like it should
# soup

# %%
title = []
for t in soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite'):
    title.append(t.get_text())
# print(title)

# %%
artist = []
for a in soup.select('div.chart-content.col-xs-12.col-sm-8 > p > em'):
    artist.append(a.get_text())
# print(artist)

# %%
popvortex_list = pd.DataFrame({"title":title,
                       "artist":artist,
                      })
popvortex_list
# Out:
#                            title                         artist
# 0                    Lovin On Me                    Jack Harlow
# 1   3D (Justin Timberlake Remix)  Jung Kook & Justin Timberlake
# 2                  Lil Boo Thang                   Paul Russell
# 3       DJ Play A Christmas Song                           Cher
# 4                    White Horse                Chris Stapleton
# ..                           ...                            ...
# 95                   Agora Hills                       Doja Cat
# 96            The New Thing Dies                       Ray Bull
# 97                  Jingle Bells                  Frank Sinatra
# 98  You're a Mean One Mr. Grinch              Thurl Ravenscroft
# 99                 World on Fire                     Nate Smith
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Web Scraping Billboard

# %%
url_bill = 'https://www.billboard.com/charts/hot-100/'

# %%
response = requests.get(url_bill)
response.status_code
# Out:
# 200

# %%
soup_bill = BeautifulSoup(response.content, "html.parser")

# %%
bill_list = []

for e in soup_bill.find_all(attrs={'class':'o-chart-results-list-row-container'}):
    bill_list.append({
        'title':e.h3.get_text(strip=True),
        'artist':e.h3.find_next('span').get_text(strip=True)
    })

# bill_list

# %%
billboard_df = pd.DataFrame(bill_list)
billboard_df
# Out:
#                                                 title  \
# 0                                        Cruel Summer
# 1                                         Lovin On Me
# 2                                  Paint The Town Red
# 3                                              Snooze
# 4   Is It Over Now? (Taylor's Version) [From The V...
# ..                                                ...
# 95                                  Mi Ex Tenia Razon
# 96                              Different 'Round Here
# 97                        But I Got A Beer In My Hand
# 98                                   Better Than Ever
# 99                                  Soak City (Do It)
#
#                                    artist
# 0                            Taylor Swift
# 1                             Jack Harlow
# 2                                Doja Cat
# 3                                     SZA
# 4                            Taylor Swift
# ..                                    ...
# 95                                Karol G
# 96       Riley Green Featuring Luke Combs
# 97                             Luke Bryan
# 98  YoungBoy Never Broke Again & Rod Wave
# 99                               310babii
#
# [100 rows x 2 columns]

# %%
# concat top 200 songs
hot_list = pd.concat([popvortex_list,billboard_df], axis = 0)
hot_list
# Out:
#                            title                                 artist
# 0                    Lovin On Me                            Jack Harlow
# 1   3D (Justin Timberlake Remix)          Jung Kook & Justin Timberlake
# 2                  Lil Boo Thang                           Paul Russell
# 3       DJ Play A Christmas Song                                   Cher
# 4                    White Horse                        Chris Stapleton
# ..                           ...                                    ...
# 95             Mi Ex Tenia Razon                                Karol G
# 96         Different 'Round Here       Riley Green Featuring Luke Combs
# 97   But I Got A Beer In My Hand                             Luke Bryan
# 98              Better Than Ever  YoungBoy Never Broke Again & Rod Wave
# 99             Soak City (Do It)                               310babii
#
# [200 rows x 2 columns]

# %%
# drop duplicates
hot_list = hot_list.drop_duplicates()
hot_list
# Out:
#                            title                                 artist
# 0                    Lovin On Me                            Jack Harlow
# 1   3D (Justin Timberlake Remix)          Jung Kook & Justin Timberlake
# 2                  Lil Boo Thang                           Paul Russell
# 3       DJ Play A Christmas Song                                   Cher
# 4                    White Horse                        Chris Stapleton
# ..                           ...                                    ...
# 95             Mi Ex Tenia Razon                                Karol G
# 96         Different 'Round Here       Riley Green Featuring Luke Combs
# 97   But I Got A Beer In My Hand                             Luke Bryan
# 98              Better Than Ever  YoungBoy Never Broke Again & Rod Wave
# 99             Soak City (Do It)                               310babii
#
# [179 rows x 2 columns]

# %%
# save to csv
hot_list.to_csv('hot_list.csv', index=False)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
pd.set_option("display.max_columns", 0)

# %% [markdown]
# ## API wrappers: Create a spotify playlist with appx 12,000 songs

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
# we will use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "5xqpyfZyS1DVysoevdVyEn")

# %%
# playlist

# %%
playlist['total']
# Out:
# 10991

# %%
# Let's look at items and total:
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
# playlist['items'] contains the tracks on the playlist
# playlist["items"][0]['track']

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("5xqpyfZyS1DVysoevdVyEn")
len(all_tracks)
# Out:
# 10991

# %%
from pandas import json_normalize
tracks2 = json_normalize(all_tracks)

# %%
tracks2.head()
# Out:
#                added_at  ...  video_thumbnail.url
# 0  2016-04-13T17:09:41Z  ...                 None
# 1  2016-04-13T17:09:41Z  ...                 None
# 2  2016-04-13T17:09:41Z  ...                 None
# 3  2016-04-13T17:09:41Z  ...                 None
# 4  2016-04-13T17:09:41Z  ...                 None
#
# [5 rows x 40 columns]

# %%
def expand_list_dict2(row):
    df = json_normalize(row['track.artists'])
    df['song_id'] = row['track.id']
    return df


tracks2['artists_dfs'] = tracks2.apply(expand_list_dict2, axis=1)

# %%
tracks2['artists_dfs'][0]
# Out:
#                                                 href  ...                 song_id
# 0  https://api.spotify.com/v1/artists/1xU878Z1QtB...  ...  3AA8xNhDC0MpqwkGX3EP5V
#
# [1 rows x 7 columns]

# %%
# now we create a new dataframe with all these artists
artist_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df in tracks2['artists_dfs']:
    #display(val)
    artist_df2 = pd.concat([artist_df2, mini_df], axis=0)
    
artist_df2
# Out:
#                                                  href  ...                 song_id
# 0   https://api.spotify.com/v1/artists/1xU878Z1QtB...  ...  3AA8xNhDC0MpqwkGX3EP5V
# 0   https://api.spotify.com/v1/artists/2oWyxHNcxMc...  ...  2i8lRhmZNKaM1ypHwRybuD
# 0   https://api.spotify.com/v1/artists/2UyhhfLOvfL...  ...  4flxgPC0426CEeSrzQIic0
# 0   https://api.spotify.com/v1/artists/1gkSl4XpHIH...  ...  1XHFob24QklIXtLRopKirJ
# 0   https://api.spotify.com/v1/artists/3GpAL7oEFD3...  ...  4JB847zlgViLq8tJIzRsZy
# ..                                                ...  ...                     ...
# 0   https://api.spotify.com/v1/artists/4HpHDJqNFP3...  ...  1v6vHkDHBjm4OHUzeOKber
# 0   https://api.spotify.com/v1/artists/2sriRQRt36D...  ...  5TN8n4LQS8Or2WEnU56pXs
# 0   https://api.spotify.com/v1/artists/54QMjE4toDf...  ...  6MEzr1cmAJi3FXBjXVXMnm
# 0   https://api.spotify.com/v1/artists/5wFXmYsg3KF...  ...  6ovSjbBKatyx9KvWsxkAZo
# 0   https://api.spotify.com/v1/artists/4LdZNE5MHGq...  ...  6CO46FIr0FSGT0h0QXjpmH
#
# [12681 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged2 = pd.merge(left=tracks2,
                    right=artist_df2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged2.head()
# Out:
#                added_at  ...                 song_id
# 0  2016-04-13T17:09:41Z  ...  3AA8xNhDC0MpqwkGX3EP5V
# 1  2016-04-13T17:09:41Z  ...  2i8lRhmZNKaM1ypHwRybuD
# 2  2016-04-13T17:09:41Z  ...  4flxgPC0426CEeSrzQIic0
# 3  2016-04-13T17:09:41Z  ...  1XHFob24QklIXtLRopKirJ
# 4  2016-04-13T17:09:41Z  ...  4JB847zlgViLq8tJIzRsZy
#
# [5 rows x 48 columns]

# %%
df_final2 = df_merged2[['track.name', 'name', 'song_id']]
df_final2
# Out:
#                         track.name  ...                 song_id
# 0            If I Ever Feel Better  ...  3AA8xNhDC0MpqwkGX3EP5V
# 1         Dance To The Underground  ...  2i8lRhmZNKaM1ypHwRybuD
# 2                        How We Do  ...  4flxgPC0426CEeSrzQIic0
# 3               Fuck the Pain Away  ...  1XHFob24QklIXtLRopKirJ
# 4                 Street Surgery 2  ...  4JB847zlgViLq8tJIzRsZy
# ...                            ...  ...                     ...
# 12676  Hate Is an Attractive Force  ...  1v6vHkDHBjm4OHUzeOKber
# 12677                     Promises  ...  5TN8n4LQS8Or2WEnU56pXs
# 12678                      16 Beat  ...  6MEzr1cmAJi3FXBjXVXMnm
# 12679     Amplified In The Silence  ...  6ovSjbBKatyx9KvWsxkAZo
# 12680               The Wrong Side  ...  6CO46FIr0FSGT0h0QXjpmH
#
# [12681 rows x 3 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final2), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final2['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 12681

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=df_final2,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                         track.name  ... time_signature
# 0            If I Ever Feel Better  ...              4
# 1         Dance To The Underground  ...              4
# 2                        How We Do  ...              4
# 3               Fuck the Pain Away  ...              4
# 4                 Street Surgery 2  ...              4
# ...                            ...  ...            ...
# 12676  Hate Is an Attractive Force  ...              4
# 12677                     Promises  ...              1
# 12678                      16 Beat  ...              4
# 12679     Amplified In The Silence  ...              4
# 12680               The Wrong Side  ...              3
#
# [12681 rows x 21 columns]

# %%
# define a function to get more playlist
def get_playlist_dataframe(sp, playlist_id):
    def expand_list_dict2(row):
        df = json_normalize(row['track.artists'])
        df['song_id'] = row['track.id']
        return df

    def fetch_audio_features(sp, id_list):
        chunks = [(i, i+100) for i in range(0, len(id_list), 100)]
        audio_features_list = []

        for chunk in chunks:
            id_list100 = id_list[chunk[0]:chunk[1]]

            # Filter out None or invalid track IDs
            id_list100 = [track_id for track_id in id_list100 if track_id is not None]

            if id_list100:
                audio_features_list += sp.audio_features(id_list100)
                sleep(randint(1, 3000) / 1000)
            else:
                # Append None for each track ID that is None
                audio_features_list += [None] * len(id_list100)

        return audio_features_list

    # Fetch all tracks from the playlist
    results = sp.user_playlist_tracks("spotify", playlist_id)
    tracks = results['items']

    while results['next'] is not None:
        results = sp.next(results)
        tracks += results['items']
        sleep(randint(1, 3000) / 1000)  # respectful nap

    # Create a DataFrame for the tracks
    tracks_df = json_normalize(tracks)

    # Create a DataFrame for the artists
    tracks_df['artists_dfs'] = tracks_df.apply(expand_list_dict2, axis=1)
    artist_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])

    for mini_df in tracks_df['artists_dfs']:
        artist_df = pd.concat([artist_df, mini_df], axis=0)

    # Merge the two dataframes, keeping only the fields needed
    df_merged = pd.merge(left=tracks_df,
                        right=artist_df,
                        how='inner',
                        left_on='track.id',
                        right_on='song_id')

    # Select the final columns
    df_final = df_merged[['track.name', 'name', 'song_id']]

    # Fetch audio features for the tracks
    id_list = df_final['song_id'].tolist()
    audio_features_list = fetch_audio_features(sp, id_list)

    # Create a DataFrame for the audio features
    audio_features_df = pd.DataFrame(audio_features_list)

    # Drop duplicates in the audio features dataframe
    audio_features_df.drop_duplicates(inplace=True)

    # Merge the final dataframe with the audio features dataframe
    df_w_audio_ft = pd.merge(left=df_final,
                             right=audio_features_df,
                             how='inner',
                             left_on='song_id',
                             right_on='id')

    return df_w_audio_ft

# %%
# Usage
playlist_id_2 = "6FKDzNYZ8IW1pvYVF4zUN2"
df_playlist_2 = get_playlist_dataframe(sp, playlist_id_2)

# %%
df_playlist_2.head()
# Out:
#              track.name         name  ... duration_ms  time_signature
# 0  Timber (feat. Ke$ha)      Pitbull  ...      204200               4
# 1  Timber (feat. Ke$ha)        Kesha  ...      204200               4
# 2             Starships  Nicki Minaj  ...      210627               4
# 3     Wild Strawberries         PNAU  ...      235107               4
# 4             Papaoutai      Stromae  ...      232147               4
#
# [5 rows x 21 columns]

# %%
df = pd.concat([df_w_audio_ft,df_playlist_2], axis = 0)

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#                                  track.name  ... time_signature
# 0                     If I Ever Feel Better  ...              4
# 1                  Dance To The Underground  ...              4
# 2                                 How We Do  ...              4
# 3                        Fuck the Pain Away  ...              4
# 4                          Street Surgery 2  ...              4
# ...                                     ...  ...            ...
# 12955    Dark Star - Homemade Weapons Remix  ...              4
# 12956               러시안 룰렛 Russian Roulette  ...              4
# 12957  Lovers on the Sun (feat. Sam Martin)  ...              4
# 12958  Lovers on the Sun (feat. Sam Martin)  ...              4
# 12959              Bass Slut - X-FIR3 Remix  ...              4
#
# [25200 rows x 21 columns]

# %%
df.nunique()
# Out:
# track.name          18353
# name                 9987
# song_id             20800
# danceability          859
# energy                942
# key                    12
# loudness             9391
# mode                    2
# speechiness          1173
# acousticness         3919
# instrumentalness     4516
# liveness             1511
# valence              1384
# tempo               14174
# type                    1
# id                  20800
# uri                 20800
# track_href          20800
# analysis_url        20800
# duration_ms         15954
# time_signature          4
# dtype: int64

# %%
df.to_csv('spotify.csv', index=False)

# %% [markdown]
# ## Unsupervised Learning: K-means clustering

# %%
import numpy as np
numerical = df.select_dtypes(include=np.number)
numerical.shape
# Out:
# (25200, 13)

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(numerical)


# Now, all features will have the same weight.
X = pd.DataFrame(X_prep,columns=numerical.columns)
X
# Out:
#        danceability    energy       key  ...     tempo  duration_ms  time_signature
# 0          0.969690 -0.791865  0.196626  ... -0.127853     0.326963        0.128801
# 1          0.411919 -0.190199  0.474030  ...  0.284604    -0.009017        0.128801
# 2          1.419709 -0.538532  1.306242  ...  0.154510    -0.141372        0.128801
# 3          1.920435  1.277021 -0.358181  ...  0.334156     0.098441        0.128801
# 4          1.235898 -0.881587  1.583645  ... -0.781004    -0.273540        0.128801
# ...             ...       ...       ...  ...       ...          ...             ...
# 25195     -1.679720  1.445909  1.028838  ...  1.820338     1.463408        0.128801
# 25196      0.785879  1.055354  0.474030  ...  0.271595    -0.468287        0.128801
# 25197      0.272477  0.992021  0.196626  ...  0.074667    -0.579251        0.128801
# 25198      0.272477  0.992021  0.196626  ...  0.074667    -0.579251        0.128801
# 25199     -1.724088  1.408965  1.306242  ...  2.025188     0.240350        0.128801
#
# [25200 rows x 13 columns]

# %%
X.to_csv('standard_cluster.csv', index=False)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X)
    silhouette.append(silhouette_score(X, kmeans.predict(X)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
# according to the graph above, I choose 8 clusters

# %%
# from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(X)
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    3350
# 1    3718
# 2    1635
# 3    5200
# 4    2972
# 5    1431
# 6    5961
# 7     933
# dtype: int64

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(X_prep)
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     4588
# 1     4885
# 2    15727
# dtype: int64

# %%
kmeans.inertia_
# Out:
# 265788.7414248842

# %%
df['cluster'] = clusters

# %%
df['song_and_artist'] = df['track.name'] + " by " + df['name']

# %%
# check one of the cluster
df[df['cluster']==7]
# Out:
# Empty DataFrame
# Columns: [track.name, name, song_id, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature, cluster, song_and_artist]
# Index: []

# %%
spotify_with_cluster = df[['song_and_artist', 'cluster']]
spotify_with_cluster
# Out:
#                                          song_and_artist  cluster
# 0                       If I Ever Feel Better by Phoenix        2
# 1                    Dance To The Underground by Radio 4        2
# 2                                How We Do by Mount Sims        2
# 3                          Fuck the Pain Away by Peaches        2
# 4                           Street Surgery 2 by Zongamin        2
# ...                                                  ...      ...
# 12955  Dark Star - Homemade Weapons Remix by Homemade...        1
# 12956              러시안 룰렛 Russian Roulette by Red Velvet        2
# 12957  Lovers on the Sun (feat. Sam Martin) by David ...        2
# 12958  Lovers on the Sun (feat. Sam Martin) by Sam Ma...        2
# 12959                   Bass Slut - X-FIR3 Remix by S3RL        2
#
# [25200 rows x 2 columns]

# %%
import pickle
# save it to pickle
scaler = StandardScaler().fit(numerical)
pickle.dump(kmeans, open('kmeans.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
# save clustered songlist to csv
df.to_csv('spotify_with_cluster.csv', index = False )

# %% [markdown]
# ## Build song recommendation function

# %%
# Get the user's input song
user_input = input("Please Enter a song: ")

# Check if the user's input song is in the Hot 200 (case-sensitive)
if (hot_list['title'].str.lower() == user_input.lower()).any():
    # If it's in the Hot 200, recommend another Hot 200 song
    recommended_hot_song = hot_list[hot_list['title'] != user_input].sample(1)
    print("You seem to enjoy hot songs! Here is a recommendation for you:")
    print(f"{recommended_hot_song['title'].values[0]} by {recommended_hot_song['artist'].values[0]}")

else:
    # If it's not in the Hot 200, fetch audio features from the Spotify API
    # and use the clustering model to recommend a song from the same cluster

    # Assume you have a pickled KMeans model saved, replace 'kmeans_model.pkl' with the actual file path
    with open('kmeans.pkl', 'rb') as model_file:
        kmeans_model = pickle.load(model_file)
    with open('scaler.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)

    # Find the song URI using Spotify search
    results = sp.search(q= user_input, type="track")

    if results['tracks']['items']:
        song_uri = results['tracks']['items'][0]['uri'].split(':')[-1]

        # Find song features using Spotify audio_features
        song_features = sp.audio_features(song_uri)

        if song_features:
            # Create a DataFrame for the audio features
            user_song_features = pd.DataFrame(song_features)
            
            # Select only numerical columns
            numerical_columns = user_song_features.select_dtypes(include=['number']).columns
            user_song_features_numeric = user_song_features[numerical_columns]

            user_song_scaled = scaler.transform(user_song_features_numeric)

            # Predict the cluster for the user's song
            user_cluster = kmeans_model.predict(user_song_scaled)

#             print("Predicted Cluster for the User's Song:", user_cluster[0])

              # recommend same cluster song
            recommended_cluster_song = spotify_with_cluster[spotify_with_cluster['cluster'] == user_cluster[0]].sample(1)

            if not recommended_cluster_song.empty:
                print("You might also like:")
                print(recommended_cluster_song['song_and_artist'].to_string(index=False))

            else:
                print("No recommendations available for the user's song cluster.")
        else:
            print("Unable to fetch audio features for the user's song.")
    else:
        print("Song not found in Spotify. Please enter another song.")
# Out:
# Please Enter a song: love you
# You might also like:
# Can’t Stop My Dreaming (Of You) by Jono Ma & Dr...
